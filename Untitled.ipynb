# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score, roc_auc_score, precision_recall_curve,auc

# %%
df = pd.read_csv("data4.csv")
df = df.rename(columns={'Attrition': 'Target'}) # Đổi tên cột Attrition thành Target
print(df.head(5))
# Out:
#   Employee ID  Monthly Income  ...  Environment Satisfaction Target
# 0   EMP_00001           17732  ...                         3      0
# 1   EMP_00002            4687  ...                         3      0
# 2   EMP_00003            3096  ...                         3      1
# 3   EMP_00004            5656  ...                         2      0
# 4   EMP_00005           18800  ...                         3      1
#
# [5 rows x 24 columns]

# %%
df_clean = df.drop(columns=['Employee ID'])
df_clean.head(5)
# Out:
#    Monthly Income  Job Satisfaction  ... Environment Satisfaction  Target
# 0           17732                 4  ...                        3       0
# 1            4687                 4  ...                        3       0
# 2            3096                 3  ...                        3       1
# 3            5656                 4  ...                        2       0
# 4           18800                 1  ...                        3       1
#
# [5 rows x 23 columns]

# %%
# Mã hóa các cột dạng chữ (Categorical) trước khi chuẩn hóa
le = LabelEncoder()
for col in df_clean.select_dtypes(include=['object']).columns:
    df_clean[col] = le.fit_transform(df_clean[col])

# %%
X = df_clean.drop(columns=['Target'])
y = df_clean['Target']

# %%
scaler = StandardScaler()
X_scaled =  scaler.fit_transform(X)

# %%
X_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
log_re = LogisticRegression()
log_re.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    y_prob = model.predict_proba(x_test)[:, 1]
    
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)
    
    # Tính PR-AUC
    precision, recall, _ = precision_recall_curve(y_test, y_prob)
    pr_auc = auc(recall, precision)
    
    return acc, f1, roc_auc, pr_auc

# Kết quả Logistic Regression
results_lr = evaluate_model(log_re, x_test, y_test)
# Kết quả Decision Tree
results_dt = evaluate_model(decision_tree, x_test, y_test)

# %%
compair = pd.DataFrame({
    'Metrics': ['Accuracy','F1-Score', 'ROC-AUC','PR-AUC'],
    'Logistic Regression': results_lr,
    'Decision Tree': results_dt
})
print(compair)
# Out:
#     Metrics  Logistic Regression  Decision Tree
# 0  Accuracy             0.798210       0.661186
# 1  F1-Score             0.000000       0.207690
# 2   ROC-AUC             0.496059       0.496384
# 3    PR-AUC             0.200498       0.287041
